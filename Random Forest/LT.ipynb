# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# Dùng cơ chế Boostrap để tạo ra bộ train, nghĩa là tạo ra n bộ train, sau đó sẽ bỏ 1 bộ train trong n bộ, và lặp lại 1 bộ. Nếu tạo ra n cây thì sẽ có n  tập train,
# ví dụ tạo ra 10 bộ
# sau đó lấy 1,2,2,3,4,5,7,8,9,10 sẽ lặp lại bộ 2 và bỏ bộ 6
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# Dùng RF để tìm feature tốt
# ![image-6.png](attachment:image-6.png)
