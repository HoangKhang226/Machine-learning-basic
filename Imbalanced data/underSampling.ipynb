# %% [markdown]
# # Under Sampling

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("points.csv",index_col=0)
df.head()
# Out:
#           0         1  target
# 0 -2.473300  0.569620       0
# 1 -1.283776  0.576974       1
# 2  1.428302  0.629649       1
# 3  2.071399  1.389588       1
# 4  1.247005  1.123625       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15000 entries, 0 to 14999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       15000 non-null  float64
#  1   1       15000 non-null  float64
#  2   target  15000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 468.8 KB

# %%
df.target.value_counts()
# Out:
# target
# 1    14185
# 0      815
# Name: count, dtype: int64

# %% [markdown]
# # visualize data

# %%
sns.scatterplot(df,x="0",y="1",hue="target")
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['0'], df['1'], df['target'], c=df['target'])

# %% [markdown]
# # Random under sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
x_rs,y_rs=RandomUnderSampler().fit_resample(df[["0","1"]],df.target)
y_rs.value_counts()
# Out:
# target
# 0    815
# 1    815
# Name: count, dtype: int64

# %%
df_S=pd.DataFrame(x_rs)
df_S["target"]=y_rs
df_S.head()
# Out:
#            0         1  target
# 0  -2.473300  0.569620       0
# 22 -1.655427  1.168923       0
# 52 -0.012906  0.989231       0
# 68 -0.841488  0.212281       0
# 74  1.169471  1.035011       0

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(df_S,x="0",y="1",hue="target")
# Out:
# <Axes: xlabel='0', ylabel='1'>
