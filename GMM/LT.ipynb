# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ý tưởng của GMM là với 1 bộ dataset, ta sẽ tìm các phân phối chuẩn của nó, trên ảnh với barplot là các điểm dữ liệu, còn các đường cong xanh và đỏ chính là các đường phân phối chuẩn.
# ![image.png](attachment:image.png)
# sau đó ta dùng công thức để xác suất để dự đoán điểm dữ liệu mới thuộc về lớp nào

# %% [markdown]
# ![image.png](attachment:image.png)
