# %% [markdown]
# Hierarchical clustering là một thuật toán thuộc nhóm Unsupervised Learning.
#
# Được sử dụng khi ta có dữ liệu không có nhãn.
#
# Tương tự như K-means, hierarchical clustering cũng nhóm các dữ liệu có đặc điểm tương tự vào cùng nhóm.
#
# Trong một số trường hợp, kết quả của hierarchical và K-Means clustering có thể tương tự

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Cách dùng

# %% [markdown]
# ## Agglomerative Clustering Algorthim

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Dendrogram

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
